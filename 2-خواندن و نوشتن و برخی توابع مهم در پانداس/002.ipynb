# %% [markdown]
# # Read Dataframe

# %%
import pandas as pd

# %%
iris = pd.read_csv('iris.csv') ##read dataset 
#pd.read_excel
#pd.read_json

# %%
iris
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
iris.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %%
iris.head(8)
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa
# 5           5.4          3.9           1.7          0.4  Setosa
# 6           4.6          3.4           1.4          0.3  Setosa
# 7           5.0          3.4           1.5          0.2  Setosa

# %%
iris.tail()
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica

# %%
iris.tail(10)
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 140           6.7          3.1           5.6          2.4  Virginica
# 141           6.9          3.1           5.1          2.3  Virginica
# 142           5.8          2.7           5.1          1.9  Virginica
# 143           6.8          3.2           5.9          2.3  Virginica
# 144           6.7          3.3           5.7          2.5  Virginica
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica

# %% [markdown]
# # Assign()
# merging the result calculation to the dataframe
# return a copy of data

# %%
iris.assign(sepal_ratio = iris['sepal.length']/iris['sepal.width'])
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety  \
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
#      sepal_ratio
# 0       1.457143
# 1       1.633333
# 2       1.468750
# 3       1.483871
# 4       1.388889
# ..           ...
# ...

# %%
iris.assign(sapat_ratio = lambda x : (x['sepal.length']/x['sepal.width']))   #with loop
#add function to assign func
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety  \
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
#      sapat_ratio
# 0       1.457143
# 1       1.633333
# 2       1.468750
# 3       1.483871
# 4       1.388889
# ..           ...
# ...

# %% [markdown]
# # Qurey over the dataset(iris)
# iris.query()

# %%
iris.query("sepal.length > 5 ").assign(
    sapat_ratio = lambda x : (x['sepal.length']/x['sepal.width'])
).plot()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\computation\scope.py:198, in Scope.resolve(self, key, is_local)
#     197 if self.has_resolvers:
# --> 198     return self.resolvers[key]
#     200 # if we're here that means that we have no locals and we also have
#     201 # no resolvers
#
# File ~\anaconda3\lib\collections\__init__.py:941, in ChainMap.__getitem__(self, key)
#     940         pass
# --> 941 return self.__missing__(key)
#
# File ~\anaconda3\lib\collections\__init__.py:933, in ChainMap.__missing__(self, key)
#     932 def __missing__(self, key):
# --> 933     raise KeyError(key)
#
# KeyError: 'sepal'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
iris.plot(kind = 'scatter', x = 'sepal.length', y ='sepal.width' )
# Out:
# <Axes: xlabel='sepal.length', ylabel='sepal.width'>

# %% [markdown]
# # W0rite Dataframe

# %%
df = pd.DataFrame(
    {
    'name':['mahdi','fatemeh','ali'],
    'sex':['male','female','male'],
    'age':[1100,18,68]
    }
)

# %%
df.to_csv('name.cvs')

# %%
df.to_dict()
# Out:
# {'name': {0: 'mahdi', 1: 'fatemeh', 2: 'ali'},
#  'sex': {0: 'male', 1: 'female', 2: 'male'},
#  'age': {0: 1100, 1: 18, 2: 68}}

# %%
df.to_excel('name.xlsx',sheet_name = 'Name' , index=False)

# %%
df.to_excel('name.xlsx',sheet_name = 'Name',index=True )

# %% [markdown]
# # Assing Realtime

# %%
dfa = pd.DataFrame({
    'a':[1 , 2 , 3],
    'b':[4, 5, 6]
}
)

# %%
dfa
# Out:
#    a  b
# 0  1  4
# 1  2  5
# 2  3  6

# %%
dfa.assign(c = lambda x : x['a'] + x['b'],
           d = lambda x : x['a'] + x['c']
          )
# Out:
#    a  b  c   d
# 0  1  4  5   6
# 1  2  5  7   9
# 2  3  6  9  12

# %% [markdown]
# # Selection

# %%
#Select column

# %%
(iris['petal.width']).head()
# Out:
# 0    0.2
# 1    0.2
# 2    0.2
# 3    0.2
# 4    0.2
# Name: petal.width, dtype: float64

# %%
#select row  by label

# %%
iris.loc[149]
# Out:
# sepal.length          5.9
# sepal.width           3.0
# petal.length          5.1
# petal.width           1.8
# variety         Virginica
# Name: 149, dtype: object

# %%
#select row  by int

# %%
iris.iloc[115]
# Out:
# sepal.length          6.4
# sepal.width           3.2
# petal.length          5.3
# petal.width           2.3
# variety         Virginica
# Name: 115, dtype: object

# %%
#silce rows type = datafrane

# %%
iris[5:10]
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 5           5.4          3.9           1.7          0.4  Setosa
# 6           4.6          3.4           1.4          0.3  Setosa
# 7           5.0          3.4           1.5          0.2  Setosa
# 8           4.4          2.9           1.4          0.2  Setosa
# 9           4.9          3.1           1.5          0.1  Setosa

# %%
#select row by boolean vector

# %%
iris['petal.length']>5 #boolean vector
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 145     True
# 146    False
# 147     True
# 148     True
# 149     True
# Name: petal.length, Length: 150, dtype: bool

# %%
iris[iris['petal.length']>5].head(20)
# Out:
#      sepal.length  sepal.width  petal.length  petal.width     variety
# 83            6.0          2.7           5.1          1.6  Versicolor
# 100           6.3          3.3           6.0          2.5   Virginica
# 101           5.8          2.7           5.1          1.9   Virginica
# 102           7.1          3.0           5.9          2.1   Virginica
# 103           6.3          2.9           5.6          1.8   Virginica
# 104           6.5          3.0           5.8          2.2   Virginica
# 105           7.6          3.0           6.6          2.1   Virginica
# 107           7.3          2.9           6.3          1.8   Virginica
# 108           6.7          2.5           5.8          1.8   Virginica
# 109           7.2          3.6           6.1          2.5   Virginica
# 110           6.5          3.2           5.1          2.0   Virginica
# 111           6.4          2.7           5.3          1.9   Virginica
# ...

# %% [markdown]
# # Remmeber

# %%
iris.describe()
# Out:
#        sepal.length  sepal.width  petal.length  petal.width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
iris.describe(include='all')
# Out:
#         sepal.length  sepal.width  petal.length  petal.width variety
# count     150.000000   150.000000    150.000000   150.000000     150
# unique           NaN          NaN           NaN          NaN       3
# top              NaN          NaN           NaN          NaN  Setosa
# freq             NaN          NaN           NaN          NaN      50
# mean        5.843333     3.057333      3.758000     1.199333     NaN
# std         0.828066     0.435866      1.765298     0.762238     NaN
# min         4.300000     2.000000      1.000000     0.100000     NaN
# 25%         5.100000     2.800000      1.600000     0.300000     NaN
# 50%         5.800000     3.000000      4.350000     1.300000     NaN
# 75%         6.400000     3.300000      5.100000     1.800000     NaN
# max         7.900000     4.400000      6.900000     2.500000     NaN

# %%
iris.describe(include='object')
# Out:
#        variety
# count      150
# unique       3
# top     Setosa
# freq        50

# %%
iris.describe(include='number')
# Out:
#        sepal.length  sepal.width  petal.length  petal.width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal.length  150 non-null    float64
#  1   sepal.width   150 non-null    float64
#  2   petal.length  150 non-null    float64
#  3   petal.width   150 non-null    float64
#  4   variety       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB
