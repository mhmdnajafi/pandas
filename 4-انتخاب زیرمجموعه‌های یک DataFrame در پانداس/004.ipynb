# %% [markdown]
# # Select subset of datafram

# %%
import pandas as pd

# %%
df = pd.read_csv('employees.csv')

# %%
df
# Out:
#     First Name  Last Name                                    Email  \
# 0         Jose      Lopez           joselopez0194@slingacademy.com
# 1        Diane     Carter         dianecarter1345@slingacademy.com
# 2       Sherry     Foster        sherryfoster2572@slingacademy.com
# 3       Brenda     Fisher        brendafisher3114@slingacademy.com
# 4       Sharon     Hunter        sharonhunter4898@slingacademy.com
# ..         ...        ...                                      ...
# 315    Michael     Hooper     michaelhooper315714@slingacademy.com
# 316  Stephanie      Lewis    stephanielewis316903@slingacademy.com
# 317      Kevin  Rodriguez    kevinrodriguez317301@slingacademy.com
# 318       Adam       Bell          adambell318709@slingacademy.com
# 319   Courtney   Mcdaniel  courtneymcdaniel319582@slingacademy.com
#
#                       Phone  Gender      Department  \
# 0      +1-971-533-4552x1542    male         Product
# 1              881.633.0107  female  Human Resource
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 320 entries, 0 to 319
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   First Name           320 non-null    object
#  1   Last Name            320 non-null    object
#  2   Email                320 non-null    object
#  3   Phone                320 non-null    object
#  4   Gender               320 non-null    object
#  5   Department           320 non-null    object
#  6   Job Title            320 non-null    object
#  7   Years Of Experience  320 non-null    int64
#  8   Salary               320 non-null    float64
# dtypes: float64(1), int64(1), object(7)
# memory usage: 22.6+ KB

# %%
df.describe()
# Out:
#        Years Of Experience        Salary
# count           320.000000    320.000000
# mean              8.003125  10407.812500
# std               4.346655   2444.064186
# min               1.000000   5500.000000
# 25%               4.000000   8500.000000
# 50%               8.000000  10500.000000
# 75%              12.000000  12500.000000
# max              15.000000  17000.000000

# %%
df.plot(kind = 'bar' , x='Years Of Experience' , y ='Salary')
# Out:
# <Axes: xlabel='Years Of Experience'>

# %%
df.hist()
# Out:
# array([[<Axes: title={'center': 'Years Of Experience'}>,
#         <Axes: title={'center': 'Salary'}>]], dtype=object)

# %%
missdata=['NaN']
taitanic = pd.read_csv('taitanic.csv',na_values=missdata)

# %%
taitanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
taitanic.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# # Specific columns from DF all rows included

# %%
ages = taitanic['Age']

# %%
ages
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
ages.head()
# Out:
# 0    22.0
# 1    38.0
# 2    26.0
# 3    35.0
# 4    35.0
# Name: Age, dtype: float64

# %%
ages.tail()
# Out:
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, dtype: float64

# %%
ages.shape
# Out:
# (891,)

# %%
print(type(ages))
# Out:
# <class 'pandas.core.series.Series'>

# %%
data = taitanic[['Age','Sex','Survived']]   # selection with [['','','',...]]

# %%
data
# Out:
#       Age     Sex  Survived
# 0    22.0    male         0
# 1    38.0  female         1
# 2    26.0  female         1
# 3    35.0  female         1
# 4    35.0    male         0
# ..    ...     ...       ...
# 886  27.0    male         0
# 887  19.0  female         1
# 888   NaN  female         0
# 889  26.0    male         1
# 890  32.0    male         0
#
# [891 rows x 3 columns]

# %%
data.shape
# Out:
# (891, 3)

# %%
print(type(data))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# # Specific ROWS from DF all rows included

# %%
above_35 = taitanic[taitanic['Age'] > 35]
above_35
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 6              7         0       1
# 11            12         1       1
# 13            14         0       3
# 15            16         1       2
# ..           ...       ...     ...
# 865          866         1       2
# 871          872         1       1
# 873          874         0       3
# 879          880         1       1
# 885          886         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 13                         Andersson, Mr. Anders Johan    male  39.0      1
# 15                    Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
class_23 = taitanic[taitanic['Pclass'].isin([2,3])]
class_23
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 0              1         0       3                   Braund, Mr. Owen Harris
# 2              3         1       3                    Heikkinen, Miss. Laina
# 4              5         0       3                  Allen, Mr. William Henry
# 5              6         0       3                          Moran, Mr. James
# 7              8         0       3            Palsson, Master. Gosta Leonard
# ..           ...       ...     ...                                       ...
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 890          891         0       3                       Dooley, Mr. Patrick
#
# ...

# %%
class_23 = taitanic[(taitanic['Pclass']==2) | (taitanic['Pclass']==3)] #  | >>> or
class_23
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 0              1         0       3                   Braund, Mr. Owen Harris
# 2              3         1       3                    Heikkinen, Miss. Laina
# 4              5         0       3                  Allen, Mr. William Henry
# 5              6         0       3                          Moran, Mr. James
# 7              8         0       3            Palsson, Master. Gosta Leonard
# ..           ...       ...     ...                                       ...
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 890          891         0       3                       Dooley, Mr. Patrick
#
# ...

# %%
#working with known ages of df
age_no_na = above_35[above_35['Age'].notna()]

# %%
age_no_na
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 6              7         0       1
# 11            12         1       1
# 13            14         0       3
# 15            16         1       2
# ..           ...       ...     ...
# 865          866         1       2
# 871          872         1       1
# 873          874         0       3
# 879          880         1       1
# 885          886         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 13                         Andersson, Mr. Anders Johan    male  39.0      1
# 15                    Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# # Specific rows and columns from DF all rows included

# %%
# the names of passengers where their age >35 ---> loc[filter , col name]
adult_names = taitanic.loc[taitanic['Age']>35 , 'Name']

# %%
adult_names
# Out:
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 6                                McCarthy, Mr. Timothy J
# 11                              Bonnell, Miss. Elizabeth
# 13                           Andersson, Mr. Anders Johan
# 15                      Hewlett, Mrs. (Mary D Kingcome)
#                              ...
# 865                             Bystrom, Mrs. (Karolina)
# 871     Beckwith, Mrs. Richard Leonard (Sallie Monypeny)
# 873                          Vander Cruyssen, Mr. Victor
# 879        Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)
# 885                 Rice, Mrs. William (Margaret Norton)
# Name: Name, Length: 217, dtype: object

# %%
type(adult_names)
# Out:
# pandas.core.series.Series

# %%
adult_names[1]
# Out:
# 'Cumings, Mrs. John Bradley (Florence Briggs Thayer)'

# %%
adult_names.index
# Out:
# Int64Index([  1,   6,  11,  13,  15,  25,  30,  33,  35,  40,
#             ...
#             854, 856, 857, 860, 862, 865, 871, 873, 879, 885],
#            dtype='int64', length=217)

# %% [markdown]
# # Rows of 10 to 25 and cols from 3 to 5

# %%
taitanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
taitanic.iloc[9:25,2:5]
# Out:
#     Pclass                                               Name     Sex
# 9        2                Nasser, Mrs. Nicholas (Adele Achem)  female
# 10       3                    Sandstrom, Miss. Marguerite Rut  female
# 11       1                           Bonnell, Miss. Elizabeth  female
# 12       3                     Saundercock, Mr. William Henry    male
# 13       3                        Andersson, Mr. Anders Johan    male
# 14       3               Vestrom, Miss. Hulda Amanda Adolfina  female
# 15       2                   Hewlett, Mrs. (Mary D Kingcome)   female
# 16       3                               Rice, Master. Eugene    male
# 17       2                       Williams, Mr. Charles Eugene    male
# 18       3  Vander Planke, Mrs. Julius (Emelia Maria Vande...  female
# 19       3                            Masselmani, Mrs. Fatima  female
# 20       2                               Fynney, Mr. Joseph J    male
# ...

# %% [markdown]
# # Assing the name of hamid to the first 3 elements of third column

# %%
taitanic.iloc[3:5,4]= 'hamid1'

# %%
taitanic.iloc[4,5]='mahdi'

# %%
taitanic.iloc[3:5]
# Out:
#   PassengerId Survived Pclass   Name     Sex    Age  SibSp  Parch Ticket  \
# 3       hamid    hamid  hamid  hamid  hamid1  hamid  hamid  hamid  hamid
# 4       hamid    hamid  hamid  hamid  hamid1  mahdi  hamid  hamid  hamid
#
#     Fare  Cabin Embarked
# 3  hamid  hamid    hamid
# 4  hamid  hamid    hamid
